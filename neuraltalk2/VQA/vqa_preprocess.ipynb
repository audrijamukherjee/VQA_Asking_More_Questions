# %%
import json
# only load trianing data for now 
train = json.load(open('../../v2_Questions_Test_mscoco/v2_OpenEnded_mscoco_test2015_questions.json', 'r'))
generated_test = json.load(open('../generated_questions_test.json', 'r'))

# %%
train['questions'][2]
# Out:
# {u'image_id': 262144,
#  u'question': u'Can you see the ball?',
#  u'question_id': 262144002}

# %%
from IPython.display import Image
relative_image_filepath = "../../val/images/train2014/COCO_train2014_"
i = 99
image_path = relative_image_filepath + str(train['questions'][i]['image_id']) + ".jpg"
print(image_path)
subtype = 'train2014'
imdir='%s/COCO_%s_%012d.jpg'
image_path1 = '../../VQA/images/' + imdir%(subtype, subtype, train['questions'][i]['image_id'])
image_path2 = '../../VQA/images/train2014/COCO_train2014_000000000025.jpg'
Image(filename = image_path1)
print(train['questions'][i]['question_id'])
# Out:
# ../../val/images/train2014/COCO_train2014_393274.jpg
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-140-70220c19a291> in <module>()
#       8 image_path1 = '../../VQA/images/' + imdir%(subtype, subtype, train['questions'][i]['image_id'])
#       9 image_path2 = '../../VQA/images/train2014/COCO_train2014_000000000025.jpg'
# ---> 10 Image(filename = image_path1)
#      11 print(train['questions'][i]['question_id'])
#
# /Users/jyon/Tools/anaconda3/envs/py27/lib/python2.7/site-packages/IPython/core/display.pyc in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     755         self.unconfined = unconfined
#     756         self.metadata = metadata
# --> 757         super(Image, self).__init__(data=data, url=url, filename=filename)
#     758
#     759         if retina:
#
# /Users/jyon/Tools/anaconda3/envs/py27/lib/python2.7/site-packages/IPython/core/display.pyc in __init__(self, data, url, filename)
#     392         self.filename = None if filename is None else unicode_type(filename)
#     393
# --> 394         self.reload()
#     395         self._check_data()
#     396
#
# /Users/jyon/Tools/anaconda3/envs/py27/lib/python2.7/site-packages/IPython/core/display.pyc in reload(self)
#     777         """Reload the raw data from file or URL."""
#     778         if self.embed:
# --> 779             super(Image,self).reload()
#     780             if self.retina:
#     781                 self._retina_shape()
#
# /Users/jyon/Tools/anaconda3/envs/py27/lib/python2.7/site-packages/IPython/core/display.pyc in reload(self)
#     410         """Reload the raw data from file or URL."""
#     411         if self.filename is not None:
# --> 412             with open(self.filename, self._read_flags) as f:
#     413                 self.data = f.read()
#     414         elif self.url is not None:
#
# IOError: [Errno 2] No such file or directory: u'../../VQA/images/train2014/COCO_train2014_000000393274.jpg'

# %%
relative_image_filepath = "../../VQA/images/train2014/COCO_train2014_"
imdir='%012d.jpg'
# 13278 
# 12034
# 4830
# 16109
# 5947
# 5018

image_path = relative_image_filepath + imdir%(12069) 
Image(filename = image_path)

# %%
# I want all questions for 2000 images in the training dataset 
itoa = {}
for q in train['questions']: 
    imgid = q['image_id']
    #print(type(imgid))
    if imgid in itoa:
        itoa[imgid].append(q['question'])
    else:
        itoa[imgid] = []
        itoa[imgid].append(q['question'])
print(len(itoa))
# Out:
# 40504

# %%
itoa[579462]
# Out:
# [u'What is the woman doing?',
#  u'What color is the walls?',
#  u'Where room is woman in?']

# %%
subtype = 'train2014'
imdir='%s/COCO_%s_%012d.jpg'
out = []
    for key in itoa:
    jimg = {}
    jimg['file_path'] = imdir%(subtype, subtype, key)
    jimg['id'] = key
    jimg['captions'] = itoa[key]
    out.append(jimg)
json.dump(out, open('coco_raw.json', 'w'))

# %%
out[0]
# Out:
# {'captions': [u'What is this photo taken looking through?',
#   u'What position is this man playing?',
#   u'What color is the players shirt?',
#   u'Is this man a professional baseball player?'],
#  'file_path': 'train2014/COCO_train2014_000000458752.jpg',
#  'id': 458752}

# %%
image_path1 = '../../VQA/images/' + imdir%(subtype, subtype, 133063)
Image(filename = image_path1)

# %%
imdir2 = 'COCO_%s_%012d.jpg'
#subtype = 'val2014'
subtype="test2015"
i = 737
image_path2 = '../../test_subset/' + imdir2%(subtype, int(generated_test["questions"][i]['image_id'][1:]))
print(generated_test["questions"][i]['image_id'])
print(generated_test["questions"][i]['question'])
Image(filename = image_path2)
# Out:
# _000000232162
# what is the man doing?
